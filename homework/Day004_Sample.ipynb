# %% [markdown]
# # 利用 Python 存取 API
#
#
# * 了解 Server Client 的架構與溝通方法
# * 知道 HTTP Request & Response 的內容
# * 什麼是 API？如何用 Python 程式存取 API 資料

# %% [markdown]
# ## 下載檔案

# %%
import requests

r = requests.get('https://api.github.com/events')
r.text
# Out:
# '[{"id":"13068779614","type":"IssueCommentEvent","actor":{"id":111974,"login":"NiLuJe","display_login":"NiLuJe","gravatar_id":"","url":"https://api.github.com/users/NiLuJe","avatar_url":"https://avatars.githubusercontent.com/u/111974?"},"repo":{"id":8986217,"name":"koreader/koreader","url":"https://api.github.com/repos/koreader/koreader"},"payload":{"action":"created","issue":{"url":"https://api.github.com/repos/koreader/koreader/issues/6299","repository_url":"https://api.github.com/repos/koreader/koreader","labels_url":"https://api.github.com/repos/koreader/koreader/issues/6299/labels{/name}","comments_url":"https://api.github.com/repos/koreader/koreader/issues/6299/comments","events_url":"https://api.github.com/repos/koreader/koreader/issues/6299/events","html_url":"https://github.com/koreader/koreader/pull/6299","id":643342400,"node_id":"MDExOlB1bGxSZXF1ZXN0NDM4MTYyMTU5","number":6299,"title":"FontDownloader plugin","user":{"login":"pazos","id":975883,"node_id":"MDQ6VXNlcjk3NTg4Mw==","avatar_url":"https://avatars2.githubusercontent.com/u/975883?v=4","gravatar_id":"","url":"https://api.github.com/users/pazos","html_url":"https://github.com/pazos","followers_url":"https://api.github.com/users/pazos/followers","following_url":"https://api.github.com/users/pazos/following{/other_user}","gists_url":"https://api.github.com/users/pazos/gists{/gist_id}","starred_url":"https://api.github.com/users/pazos/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/pazos/subscriptions","organizations_url":"https://api.github.com/users/pazos/orgs","repos_url":"https://api.github.com/users/pazos/repos","events_url":"https://api.github.com/users/pazos/events{/privacy}","received_events_url":"https://api.github.com/users/pazos/received_events","type":"User","site_admin":false},"labels":[{"id":1219506042,"node_id":"MDU6TGFiZWwxMjE5NTA2MDQy","url":"https://api.github.com/repos/koreader/koreader/labels/Plugin","name":"Plugin","color":"abff51","default":false,"description":""}],"state":"open","locked":false,"assignee":null,"assignees":[],"milestone":{"url":"https://api.github.com/repos/koreader/koreader/milestones/27","html_url":"https://github.com/koreader/koreader/milestone/27","labels_url":"https://api.github.com/repos/koreader/koreader/milestones/27/labels","id":5315004,"node_id":"MDk6TWlsZXN0b25lNTMxNTAwNA==","number":27,"title":"2020.08","description":"","creator":{"login":"Frenzie","id":202757,"node_id":"MDQ6VXNlcjIwMjc1Nw==","avatar_url":"https://avatars2.githubusercontent.com/u/202757?v=4","gravatar_id":"","url":"https://api.github.com/users/Frenzie","html_url":"https://github.com/Frenzie","followers_url":"https://api.github.com/users/Frenzie/followers","following_url":"https://api.github.com/users/Frenzie/following{/other_user}","gists_url":"https://api.github.com/users/Frenzie/gists{/gist_id}","starred_url":"https://api.github.com/users/Frenzie/starred{/owner}{/repo}","subscriptions_url":"https://api.github.com/users/Frenzie/subscriptions","organizations_url":"https://api.github.com/users/Frenzie/orgs","repos_url":"https://api.github.com/users/Frenzie/repos","events_url":"https://api.github.com/users/Frenzie/events{/privacy}","received_events_url":"https://api.github.com/users/Frenzie/received_events","type":"User","site_admin":false},"open_issues":15,"closed_issues":35,"state":"open","created_at":"2020-04-16T09:19:53Z","updated_at":"2020-07-30T20:58:01Z","due_on":"2020-08-08T07:00:00Z","closed_at":null},"comments":35,"created_at":"2020-06-22T20:31:59Z","updated_at":"2020-07-31T04:41:30Z","closed_at":null,"author_association":"CONTRIBUTOR","active_lock_reason":null,"pull_request":{"url":"https://api.github.com/repos/koreader/koreader/pulls/6299","html_url":"https://github.com/koreader/koreader/pull/6299","diff_url":"https://github.com/koreader/koreader/pull/6299.diff","patch_url":"https://github.com/koreader/koreader/pull/6299.patch"},"body":"Tries to showcase my proposal in #6272 (and the feedback received that some g ...

# %%
import json

json.loads(r.text)
# Out:
# [{'id': '13068779614',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 111974,
#    'login': 'NiLuJe',
#    'display_login': 'NiLuJe',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/NiLuJe',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/111974?'},
#   'repo': {'id': 8986217,
#    'name': 'koreader/koreader',
#    'url': 'https://api.github.com/repos/koreader/koreader'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/koreader/koreader/issues/6299',
#     'repository_url': 'https://api.github.com/repos/koreader/koreader',
#     'labels_url': 'https://api.github.com/repos/koreader/koreader/issues/6299/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/koreader/koreader/issues/6299/comments',
#     'events_url': 'https://api.github.com/repos/koreader/koreader/issues/6299/events',
#     'html_url': 'https://github.com/koreader/koreader/pull/6299',
#     'id': 643342400,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDM4MTYyMTU5',
#     'number': 6299,
#     'title': 'FontDownloader plugin',
#     'user': {'login': 'pazos',
#      'id': 975883,
#      'node_id': 'MDQ6VXNlcjk3NTg4Mw==',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/975883?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/pazos',
#      'html_url': 'https://github.com/pazos',
#      'followers_url': 'https://api.github.com/users/pazos/followers',
#      'following_url': 'https://api.github.com/users/pazos/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/pazos/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/pazos/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/pazos/subscriptions',
#      'organizations_url': 'https://api.github.com/users/pazos/orgs',
#      'repos_url': 'https://api.github.com/users/pazos/repos',
#      'events_url': 'https://api.github.com/users/pazos/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/pazos/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1219506042,
#       'node_id': 'MDU6TGFiZWwxMjE5NTA2MDQy',
#       'url': 'https://api.github.com/repos/koreader/koreader/labels/Plugin',
#       'name': 'Plugin',
#       'color': 'abff51',
#       'default': False,
#       'description': ''}],
#     'state': 'open',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': {'url': 'https://api.github.com/repos/koreader/koreader/milestones/27',
#      'html_url': 'https://github.com/koreader/koreader/milestone/27',
#      'labels_url': 'https://api.github.com/repos/koreader/koreader/milestones/27/labels',
#      'id': 5315004,
#      'node_id': 'MDk6TWlsZXN0b25lNTMxNTAwNA==',
#      'number': 27,
#      'title': '2020.08',
#      'description': '',
#      'creator': {'login': 'Frenzie',
#       'id': 202757,
#       'node_id': 'MDQ6VXNlcjIwMjc1Nw==',
#       'avatar_url': 'https://avatars2.githubusercontent.com/u/202757?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Frenzie',
#       'html_url': 'https://github.com/Frenzie',
#       'followers_url': 'https://api.github.com/users/Frenzie/followers',
#       'following_url': 'https://api.github.com/users/Frenzie/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Frenzie/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Frenzie/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Frenzie/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Frenzie/orgs',
#       'repos_url': 'https://api.github.com/users/Frenzie/repos',
#       'events_url': 'https://api.github.com/users/Frenzie/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Frenzie/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'open_issues': 15,
#      'closed_issues': 35,
#      'state': 'open',
#      'created_at': '2020-04-16T09:19:53Z',
#      'updated_at': '2020-07-30T20:58:01Z',
#      'due_on': '2020-08-08T07:00:00Z',
#      'closed_at': None},
#     'comments': 35,
#     'created_at': '2020-06-22T20:31:59Z',
#     'updated_at': '2020-07-31T04:41:30Z',
#     'closed_at': None,
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/koreader/koreader/pulls/6299',
#      'html_url': 'https://github.com/koreader/koreader/pull/6299',
#      'diff_url': 'https://github.com/koreader/koreader/pull/6299.diff',
#      'patch_url': 'https://github.com/koreader/koreader/pull/6299.patch'},
#     'body': 'Tries to showcase my proposal in #6272 (and the feedback received that some gfonts were not optimal).\r\n\r\nIt is still very much a draft, but shows how to display a few fonts as featured and how to use our own alternatives instead of google fonts. At the same time makes available the Google Foo for new users.\r\n\r\nFonts can be navigated by: featured, language (glyph support), category (sans, serif, display...), date of last modification (last week, month or year, older) and the whole ~1000 fonts alphabetically.\r\n\r\nSince the font table is tiny(1MB) we store that in the cache and just require a network connection when we\'re going to download fonts. On download all variants for a given font are downloaded.\r\n\r\nAnd yeah, the look & feel is basically the same that calibre search metadata, because it is a low-effort copy!!!\r\n\r\n<!-- Reviewable:start -->\r\n---\r\nThis change is\u2002[<img src="https://reviewable.io/review_button.svg" height="34" align="absmiddle" alt="Reviewable"/>](https://reviewable.io/reviews/koreader/koreader/6299)\r\n<!-- Reviewable:end -->\r\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/koreader/koreader/issues/comments/666915337',
#     'html_url': 'https://github.com/koreader/koreader/pull/6299#issuecomment-666915337',
#     'issue_url': 'https://api.github.com/repos/koreader/koreader/issues/6299',
#     'id': 666915337,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY2NjkxNTMzNw==',
#     'user': {'login': 'NiLuJe',
#      'id': 111974,
#      'node_id': 'MDQ6VXNlcjExMTk3NA==',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/111974?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/NiLuJe',
#      'html_url': 'https://github.com/NiLuJe',
#      'followers_url': 'https://api.github.com/users/NiLuJe/followers',
#      'following_url': 'https://api.github.com/users/NiLuJe/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/NiLuJe/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/NiLuJe/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/NiLuJe/subscriptions',
#      'organizations_url': 'https://api.github.com/users/NiLuJe/orgs',
#      'repos_url': 'https://api.github.com/users/NiLuJe/repos',
#      'events_url': 'https://api.github.com/users/NiLuJe/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/NiLuJe/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-07-31T04:41:30Z',
#     'updated_at': '2020-07-31T04:41:30Z',
#     'author_association': 'MEMBER',
#     'body': "Random comment to mention that I updated Literata to Literata 3.002 (which shouldn't change much, but, hey, bigger numbers are better, right? :D).",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z',
#   'org': {'id': 3957564,
#    'login': 'koreader',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/koreader',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3957564?'}},
#  {'id': '13068779611',
#   'type': 'PushEvent',
#   'actor': {'id': 15176488,
#    'login': 'chenziao',
#    'display_login': 'chenziao',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/chenziao',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/15176488?'},
#   'repo': {'id': 283930663,
#    'name': 'chenziao/bmtk-develop-zc',
#    'url': 'https://api.github.com/repos/chenziao/bmtk-develop-zc'},
#   'payload': {'push_id': 5459515820,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/develop-zc',
#    'head': '9a72a26ef53000688c834cc335e72b9b6332f581',
#    'before': 'b40ff493b493422d350fd9775405af618a69900f',
#    'commits': [{'sha': '9a72a26ef53000688c834cc335e72b9b6332f581',
#      'author': {'email': 'chen8a803@gmail.com', 'name': 'chenziao'},
#      'message': 'adding distance limit in ecp calculation',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/chenziao/bmtk-develop-zc/commits/9a72a26ef53000688c834cc335e72b9b6332f581'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779610',
#   'type': 'PushEvent',
#   'actor': {'id': 25622080,
#    'login': 'dbousfira',
#    'display_login': 'dbousfira',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dbousfira',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/25622080?'},
#   'repo': {'id': 280759778,
#    'name': 'folivier03/mes-vacance-en-France',
#    'url': 'https://api.github.com/repos/folivier03/mes-vacance-en-France'},
#   'payload': {'push_id': 5459515819,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/release-0.0.1',
#    'head': '1d3d0d1586e91736d9547436282d3f2329d7bfa2',
#    'before': 'bcc6005256ba2a5cac37eee9060c11d7aecbbf8b',
#    'commits': [{'sha': '1d3d0d1586e91736d9547436282d3f2329d7bfa2',
#      'author': {'email': 'd.bousfira@hotmail.fr', 'name': 'Djamel Bousfira'},
#      'message': 'feat: more prefs on co3 img',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/folivier03/mes-vacance-en-France/commits/1d3d0d1586e91736d9547436282d3f2329d7bfa2'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779607',
#   'type': 'PushEvent',
#   'actor': {'id': 69026078,
#    'login': 'zoepomphrett',
#    'display_login': 'zoepomphrett',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/zoepomphrett',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/69026078?'},
#   'repo': {'id': 283934255,
#    'name': 'zoepomphrett/blog',
#    'url': 'https://api.github.com/repos/zoepomphrett/blog'},
#   'payload': {'push_id': 5459515817,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'e4c75bc186b91e278da1ff8ef458f8283885e0bb',
#    'before': '76ec9e5f815d440156f1fb31e5eaf63b6efc42bd',
#    'commits': [{'sha': 'e4c75bc186b91e278da1ff8ef458f8283885e0bb',
#      'author': {'email': 'finlayacourt@icloud.com', 'name': 'Finlay A’Court'},
#      'message': 'Disable drafts',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/zoepomphrett/blog/commits/e4c75bc186b91e278da1ff8ef458f8283885e0bb'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779603',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 1317309,
#    'login': 'HeartSaVioR',
#    'display_login': 'HeartSaVioR',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/HeartSaVioR',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1317309?'},
#   'repo': {'id': 17165658,
#    'name': 'apache/spark',
#    'url': 'https://api.github.com/repos/apache/spark'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/apache/spark/issues/29289',
#     'repository_url': 'https://api.github.com/repos/apache/spark',
#     'labels_url': 'https://api.github.com/repos/apache/spark/issues/29289/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/apache/spark/issues/29289/comments',
#     'events_url': 'https://api.github.com/repos/apache/spark/issues/29289/events',
#     'html_url': 'https://github.com/apache/spark/pull/29289',
#     'id': 667805114,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDU4NDA1ODA0',
#     'number': 29289,
#     'title': '[SPARK-32482][SS][TESTS] Eliminate deprecated poll(long) API calls to avoid infinite wait in tests',
#     'user': {'login': 'gaborgsomogyi',
#      'id': 18561820,
#      'node_id': 'MDQ6VXNlcjE4NTYxODIw',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/18561820?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/gaborgsomogyi',
#      'html_url': 'https://github.com/gaborgsomogyi',
#      'followers_url': 'https://api.github.com/users/gaborgsomogyi/followers',
#      'following_url': 'https://api.github.com/users/gaborgsomogyi/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/gaborgsomogyi/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/gaborgsomogyi/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/gaborgsomogyi/subscriptions',
#      'organizations_url': 'https://api.github.com/users/gaborgsomogyi/orgs',
#      'repos_url': 'https://api.github.com/users/gaborgsomogyi/repos',
#      'events_url': 'https://api.github.com/users/gaborgsomogyi/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/gaborgsomogyi/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [{'id': 1984378631,
#       'node_id': 'MDU6TGFiZWwxOTg0Mzc4NjMx',
#       'url': 'https://api.github.com/repos/apache/spark/labels/DSTREAM',
#       'name': 'DSTREAM',
#       'color': 'ededed',
#       'default': False,
#       'description': None},
#      {'id': 1405794576,
#       'node_id': 'MDU6TGFiZWwxNDA1Nzk0NTc2',
#       'url': 'https://api.github.com/repos/apache/spark/labels/SQL',
#       'name': 'SQL',
#       'color': 'ededed',
#       'default': False,
#       'description': None},
#      {'id': 1406587328,
#       'node_id': 'MDU6TGFiZWwxNDA2NTg3MzI4',
#       'url': 'https://api.github.com/repos/apache/spark/labels/STRUCTURED%20STREAMING',
#       'name': 'STRUCTURED STREAMING',
#       'color': 'ededed',
#       'default': False,
#       'description': None}],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 8,
#     'created_at': '2020-07-29T12:26:49Z',
#     'updated_at': '2020-07-31T04:41:30Z',
#     'closed_at': '2020-07-31T04:40:58Z',
#     'author_association': 'CONTRIBUTOR',
#     'active_lock_reason': None,
#     'pull_request': {'url': 'https://api.github.com/repos/apache/spark/pulls/29289',
#      'html_url': 'https://github.com/apache/spark/pull/29289',
#      'diff_url': 'https://github.com/apache/spark/pull/29289.diff',
#      'patch_url': 'https://github.com/apache/spark/pull/29289.patch'},
#     'body': "### What changes were proposed in this pull request?\r\nStructured Streaming Kafka connector tests are now using a deprecated `poll(long)` API which could cause infinite wait. In this PR I've eliminated these calls and replaced them with `AdminClient`.\r\n\r\n### Why are the changes needed?\r\nDeprecated `poll(long)` API calls.\r\n\r\n### Does this PR introduce _any_ user-facing change?\r\nNo.\r\n\r\n### How was this patch tested?\r\nExisting unit tests.\r\n",
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/apache/spark/issues/comments/666915336',
#     'html_url': 'https://github.com/apache/spark/pull/29289#issuecomment-666915336',
#     'issue_url': 'https://api.github.com/repos/apache/spark/issues/29289',
#     'id': 666915336,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY2NjkxNTMzNg==',
#     'user': {'login': 'HeartSaVioR',
#      'id': 1317309,
#      'node_id': 'MDQ6VXNlcjEzMTczMDk=',
#      'avatar_url': 'https://avatars2.githubusercontent.com/u/1317309?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/HeartSaVioR',
#      'html_url': 'https://github.com/HeartSaVioR',
#      'followers_url': 'https://api.github.com/users/HeartSaVioR/followers',
#      'following_url': 'https://api.github.com/users/HeartSaVioR/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/HeartSaVioR/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/HeartSaVioR/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/HeartSaVioR/subscriptions',
#      'organizations_url': 'https://api.github.com/users/HeartSaVioR/orgs',
#      'repos_url': 'https://api.github.com/users/HeartSaVioR/repos',
#      'events_url': 'https://api.github.com/users/HeartSaVioR/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/HeartSaVioR/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-07-31T04:41:30Z',
#     'updated_at': '2020-07-31T04:41:30Z',
#     'author_association': 'CONTRIBUTOR',
#     'body': 'Thanks! Merged into master.',
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z',
#   'org': {'id': 47359,
#    'login': 'apache',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/apache',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/47359?'}},
#  {'id': '13068779608',
#   'type': 'ForkEvent',
#   'actor': {'id': 30906649,
#    'login': 'QtacierP',
#    'display_login': 'QtacierP',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/QtacierP',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/30906649?'},
#   'repo': {'id': 229366840,
#    'name': 'Jeff-Zilence/Explain_Metric_Learning',
#    'url': 'https://api.github.com/repos/Jeff-Zilence/Explain_Metric_Learning'},
#   'payload': {'forkee': {'id': 283943782,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyODM5NDM3ODI=',
#     'name': 'Explain_Metric_Learning',
#     'full_name': 'QtacierP/Explain_Metric_Learning',
#     'private': False,
#     'owner': {'login': 'QtacierP',
#      'id': 30906649,
#      'node_id': 'MDQ6VXNlcjMwOTA2NjQ5',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/30906649?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/QtacierP',
#      'html_url': 'https://github.com/QtacierP',
#      'followers_url': 'https://api.github.com/users/QtacierP/followers',
#      'following_url': 'https://api.github.com/users/QtacierP/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/QtacierP/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/QtacierP/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/QtacierP/subscriptions',
#      'organizations_url': 'https://api.github.com/users/QtacierP/orgs',
#      'repos_url': 'https://api.github.com/users/QtacierP/repos',
#      'events_url': 'https://api.github.com/users/QtacierP/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/QtacierP/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/QtacierP/Explain_Metric_Learning',
#     'description': 'Code for paper: "Visual Explanation for Deep Metric Learning"',
#     'fork': True,
#     'url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning',
#     'forks_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/forks',
#     'keys_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/teams',
#     'hooks_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/hooks',
#     'issue_events_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/events',
#     'assignees_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/tags',
#     'blobs_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/languages',
#     'stargazers_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/stargazers',
#     'contributors_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/contributors',
#     'subscribers_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/subscribers',
#     'subscription_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/subscription',
#     'commits_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/merges',
#     'archive_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/downloads',
#     'issues_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/QtacierP/Explain_Metric_Learning/deployments',
#     'created_at': '2020-07-31T04:41:30Z',
#     'updated_at': '2020-07-31T04:41:28Z',
#     'pushed_at': '2020-01-06T04:03:13Z',
#     'git_url': 'git://github.com/QtacierP/Explain_Metric_Learning.git',
#     'ssh_url': 'git@github.com:QtacierP/Explain_Metric_Learning.git',
#     'clone_url': 'https://github.com/QtacierP/Explain_Metric_Learning.git',
#     'svn_url': 'https://github.com/QtacierP/Explain_Metric_Learning',
#     'homepage': 'https://arxiv.org/abs/1909.12977',
#     'size': 3026,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': True,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': None,
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779596',
#   'type': 'ForkEvent',
#   'actor': {'id': 7105473,
#    'login': 'bhardwajRahul',
#    'display_login': 'bhardwajRahul',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/bhardwajRahul',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/7105473?'},
#   'repo': {'id': 101212460,
#    'name': 'styfle/awesome-online-ide',
#    'url': 'https://api.github.com/repos/styfle/awesome-online-ide'},
#   'payload': {'forkee': {'id': 283943781,
#     'node_id': 'MDEwOlJlcG9zaXRvcnkyODM5NDM3ODE=',
#     'name': 'awesome-online-ide',
#     'full_name': 'bhardwajRahul/awesome-online-ide',
#     'private': False,
#     'owner': {'login': 'bhardwajRahul',
#      'id': 7105473,
#      'node_id': 'MDQ6VXNlcjcxMDU0NzM=',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/7105473?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/bhardwajRahul',
#      'html_url': 'https://github.com/bhardwajRahul',
#      'followers_url': 'https://api.github.com/users/bhardwajRahul/followers',
#      'following_url': 'https://api.github.com/users/bhardwajRahul/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/bhardwajRahul/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/bhardwajRahul/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/bhardwajRahul/subscriptions',
#      'organizations_url': 'https://api.github.com/users/bhardwajRahul/orgs',
#      'repos_url': 'https://api.github.com/users/bhardwajRahul/repos',
#      'events_url': 'https://api.github.com/users/bhardwajRahul/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/bhardwajRahul/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'html_url': 'https://github.com/bhardwajRahul/awesome-online-ide',
#     'description': '🌩️ A list of awesome online development environments',
#     'fork': True,
#     'url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide',
#     'forks_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/forks',
#     'keys_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/keys{/key_id}',
#     'collaborators_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/collaborators{/collaborator}',
#     'teams_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/teams',
#     'hooks_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/hooks',
#     'issue_events_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/issues/events{/number}',
#     'events_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/events',
#     'assignees_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/assignees{/user}',
#     'branches_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/branches{/branch}',
#     'tags_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/tags',
#     'blobs_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/git/blobs{/sha}',
#     'git_tags_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/git/tags{/sha}',
#     'git_refs_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/git/refs{/sha}',
#     'trees_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/git/trees{/sha}',
#     'statuses_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/statuses/{sha}',
#     'languages_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/languages',
#     'stargazers_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/stargazers',
#     'contributors_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/contributors',
#     'subscribers_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/subscribers',
#     'subscription_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/subscription',
#     'commits_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/commits{/sha}',
#     'git_commits_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/git/commits{/sha}',
#     'comments_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/comments{/number}',
#     'issue_comment_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/issues/comments{/number}',
#     'contents_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/contents/{+path}',
#     'compare_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/compare/{base}...{head}',
#     'merges_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/merges',
#     'archive_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/{archive_format}{/ref}',
#     'downloads_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/downloads',
#     'issues_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/issues{/number}',
#     'pulls_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/pulls{/number}',
#     'milestones_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/milestones{/number}',
#     'notifications_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/notifications{?since,all,participating}',
#     'labels_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/labels{/name}',
#     'releases_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/releases{/id}',
#     'deployments_url': 'https://api.github.com/repos/bhardwajRahul/awesome-online-ide/deployments',
#     'created_at': '2020-07-31T04:41:29Z',
#     'updated_at': '2020-07-29T11:37:46Z',
#     'pushed_at': '2020-07-28T21:28:32Z',
#     'git_url': 'git://github.com/bhardwajRahul/awesome-online-ide.git',
#     'ssh_url': 'git@github.com:bhardwajRahul/awesome-online-ide.git',
#     'clone_url': 'https://github.com/bhardwajRahul/awesome-online-ide.git',
#     'svn_url': 'https://github.com/bhardwajRahul/awesome-online-ide',
#     'homepage': 'https://styfle.dev/projects/awesome-online-ide',
#     'size': 179,
#     'stargazers_count': 0,
#     'watchers_count': 0,
#     'language': None,
#     'has_issues': False,
#     'has_projects': True,
#     'has_downloads': True,
#     'has_wiki': False,
#     'has_pages': False,
#     'forks_count': 0,
#     'mirror_url': None,
#     'archived': False,
#     'disabled': False,
#     'open_issues_count': 0,
#     'license': {'key': 'other',
#      'name': 'Other',
#      'spdx_id': 'NOASSERTION',
#      'url': None,
#      'node_id': 'MDc6TGljZW5zZTA='},
#     'forks': 0,
#     'open_issues': 0,
#     'watchers': 0,
#     'default_branch': 'master',
#     'public': True}},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779593',
#   'type': 'ReleaseEvent',
#   'actor': {'id': 63887171,
#    'login': 'DanielW705',
#    'display_login': 'DanielW705',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DanielW705',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/63887171?'},
#   'repo': {'id': 282383587,
#    'name': 'DanielW705/node-resserver',
#    'url': 'https://api.github.com/repos/DanielW705/node-resserver'},
#   'payload': {'action': 'published',
#    'release': {'url': 'https://api.github.com/repos/DanielW705/node-resserver/releases/29148899',
#     'assets_url': 'https://api.github.com/repos/DanielW705/node-resserver/releases/29148899/assets',
#     'upload_url': 'https://uploads.github.com/repos/DanielW705/node-resserver/releases/29148899/assets{?name,label}',
#     'html_url': 'https://github.com/DanielW705/node-resserver/releases/tag/v0.0.5',
#     'id': 29148899,
#     'node_id': 'MDc6UmVsZWFzZTI5MTQ4ODk5',
#     'tag_name': 'v0.0.5',
#     'target_commitish': 'master',
#     'name': 'Version Beta 0.0.5',
#     'draft': False,
#     'author': {'login': 'DanielW705',
#      'id': 63887171,
#      'node_id': 'MDQ6VXNlcjYzODg3MTcx',
#      'avatar_url': 'https://avatars0.githubusercontent.com/u/63887171?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/DanielW705',
#      'html_url': 'https://github.com/DanielW705',
#      'followers_url': 'https://api.github.com/users/DanielW705/followers',
#      'following_url': 'https://api.github.com/users/DanielW705/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/DanielW705/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/DanielW705/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/DanielW705/subscriptions',
#      'organizations_url': 'https://api.github.com/users/DanielW705/orgs',
#      'repos_url': 'https://api.github.com/users/DanielW705/repos',
#      'events_url': 'https://api.github.com/users/DanielW705/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/DanielW705/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'prerelease': False,
#     'created_at': '2020-07-31T04:39:36Z',
#     'published_at': '2020-07-31T04:41:30Z',
#     'assets': [],
#     'tarball_url': 'https://api.github.com/repos/DanielW705/node-resserver/tarball/v0.0.5',
#     'zipball_url': 'https://api.github.com/repos/DanielW705/node-resserver/zipball/v0.0.5',
#     'body': '## Todavia esta en Beta\r\n-- Esta version ya incluye google sign in, para que el usuario pueda ingresar por gmail a la aplicacion'}},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779585',
#   'type': 'PushEvent',
#   'actor': {'id': 3490170,
#    'login': 'DotnetChen',
#    'display_login': 'DotnetChen',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/DotnetChen',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/3490170?'},
#   'repo': {'id': 238119324,
#    'name': 'DotnetChen/mohw-mask',
#    'url': 'https://api.github.com/repos/DotnetChen/mohw-mask'},
#   'payload': {'push_id': 5459515807,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '730f20f6f8e6012e6131e5e97382fee6c5d58250',
#    'before': '19c0bbdc3d48f05678f077f7ca15a1bebc76804f',
#    'commits': [{'sha': '730f20f6f8e6012e6131e5e97382fee6c5d58250',
#      'author': {'email': 'pupu721@gmail.com', 'name': 'Pupu(DotNet)'},
#      'message': '更新 maskdata_auto.csv (from auto)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/DotnetChen/mohw-mask/commits/730f20f6f8e6012e6131e5e97382fee6c5d58250'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779591',
#   'type': 'WatchEvent',
#   'actor': {'id': 67019879,
#    'login': 'lailaarzumanara',
#    'display_login': 'lailaarzumanara',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/lailaarzumanara',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/67019879?'},
#   'repo': {'id': 228087125,
#    'name': 'rahman-ishtiyak/Machine_learning',
#    'url': 'https://api.github.com/repos/rahman-ishtiyak/Machine_learning'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779580',
#   'type': 'PushEvent',
#   'actor': {'id': 1547007,
#    'login': 'victordibia',
#    'display_login': 'victordibia',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/victordibia',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/1547007?'},
#   'repo': {'id': 265138409,
#    'name': 'victordibia/neuralqa',
#    'url': 'https://api.github.com/repos/victordibia/neuralqa'},
#   'payload': {'push_id': 5459515806,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/dev',
#    'head': 'c249e973dd6937a34b380ebdf78ab07290f3dd79',
#    'before': 'a19971b0402fe7f60707c54bfffb633cbec556eb',
#    'commits': [{'sha': 'c249e973dd6937a34b380ebdf78ab07290f3dd79',
#      'author': {'email': 'victor.dibia@gmail.com', 'name': 'Victor Dibia'},
#      'message': 'docs update',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/victordibia/neuralqa/commits/c249e973dd6937a34b380ebdf78ab07290f3dd79'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779571',
#   'type': 'PushEvent',
#   'actor': {'id': 8465699,
#    'login': '5d2',
#    'display_login': '5d2',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/5d2',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/8465699?'},
#   'repo': {'id': 281299666,
#    'name': '5d2/images',
#    'url': 'https://api.github.com/repos/5d2/images'},
#   'payload': {'push_id': 5459515801,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': '66a40cdddc41e1489f1d49ec984947df64772b75',
#    'before': '14810fc1a990e72b1a41aa52d9ad379b2593c6a1',
#    'commits': [{'sha': '66a40cdddc41e1489f1d49ec984947df64772b75',
#      'author': {'email': 'lxnan@live.com', 'name': '5d2'},
#      'message': 'commit from Mars',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/5d2/images/commits/66a40cdddc41e1489f1d49ec984947df64772b75'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779581',
#   'type': 'WatchEvent',
#   'actor': {'id': 12422482,
#    'login': 'Kaeptenblaubaer',
#    'display_login': 'Kaeptenblaubaer',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Kaeptenblaubaer',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/12422482?'},
#   'repo': {'id': 112953694,
#    'name': 'digitallyinduced/ihp',
#    'url': 'https://api.github.com/repos/digitallyinduced/ihp'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z',
#   'org': {'id': 42464262,
#    'login': 'digitallyinduced',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/digitallyinduced',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/42464262?'}},
#  {'id': '13068779567',
#   'type': 'CreateEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 89935412,
#    'name': 'danielbayerlein/dashboard',
#    'url': 'https://api.github.com/repos/danielbayerlein/dashboard'},
#   'payload': {'ref': 'dependabot/npm_and_yarn/babel-plugin-styled-components-1.11.1',
#    'ref_type': 'branch',
#    'master_branch': 'master',
#    'description': '📺 Create your own team dashboard with custom widgets. Built with Next.js, React, styled-components and polished.',
#    'pusher_type': 'user'},
#   'public': True,
#   'created_at': '2020-07-31T04:41:30Z'},
#  {'id': '13068779568',
#   'type': 'PullRequestEvent',
#   'actor': {'id': 27856297,
#    'login': 'dependabot-preview[bot]',
#    'display_login': 'dependabot-preview',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/dependabot-preview[bot]',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/27856297?'},
#   'repo': {'id': 138642657,
#    'name': 'Borewit/music-metadata-browser',
#    'url': 'https://api.github.com/repos/Borewit/music-metadata-browser'},
#   'payload': {'action': 'closed',
#    'number': 301,
#    'pull_request': {'url': 'https://api.github.com/repos/Borewit/music-metadata-browser/pulls/301',
#     'id': 459773759,
#     'node_id': 'MDExOlB1bGxSZXF1ZXN0NDU5NzczNzU5',
#     'html_url': 'https://github.com/Borewit/music-metadata-browser/pull/301',
#     'diff_url': 'https://github.com/Borewit/music-metadata-browser/pull/301.diff',
#     'patch_url': 'https://github.com/Borewit/music-metadata-browser/pull/301.patch',
#     'issue_url': 'https://api.github.com/repos/Borewit/music-metadata-browser/issues/301',
#     'number': 301,
#     'state': 'closed',
#     'locked': False,
#     'title': 'Bump webpack from 4.44.0 to 4.44.1',
#     'user': {'login': 'dependabot-preview[bot]',
#      'id': 27856297,
#      'node_id': 'MDM6Qm90Mjc4NTYyOTc=',
#      'avatar_url': 'https://avatars3.githubusercontent.com/in/2141?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D',
#      'html_url': 'https://github.com/apps/dependabot-preview',
#      'followers_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/followers',
#      'following_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/subscriptions',
#      'organizations_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/orgs',
#      'repos_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/repos',
#      'events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/dependabot-preview%5Bbot%5D/received_events',
#      'type': 'Bot',
#      'site_admin': False},
#     'body': 'Bumps [webpack](https://github.com/webpack/webpack) from 4.44.0 to 4.44.1.\n<details>\n<summary>Release notes</summary>\n<p><em>Sourced from <a href="https://github.com/webpack/webpack/releases">webpack\'s releases</a>.</em></p>\n<blockquote>\n<h2>v4.44.1</h2>\n<h1>Bugfixes</h1>\n<ul>\n<li>fix bug in sideEffects optimization when using <code>export * from &quot;non-esm&quot;</code> and a default export.</li>\n<li>add missing optional peerDependencies for webpack-cli and webpack-command to support Yarn 2</li>\n</ul>\n</blockquote>\n</details>\n<details>\n<summary>Commits</summary>\n<ul>\n<li><a href="https://github.com/webpack/webpack/commit/cd4af164784f3938353102179adfcbcf8f53949d"><code>cd4af16</code></a> 4.44.1</li>\n<li><a href="https://github.com/webpack/webpack/commit/7895778cacbd1dd1d51659ac32971db279659aaf"><code>7895778</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/webpack/webpack/issues/11244">#11244</a> from webpack/bugfix/dynamic-reexport-default</li>\n<li><a href="https://github.com/webpack/webpack/commit/46304c888f2b066e358339df62ac7fd89606d433"><code>46304c8</code></a> ignore default export when reexporting a dynamic module</li>\n<li><a href="https://github.com/webpack/webpack/commit/91e81c8d19fa9e03768797a6fda34231b65963b1"><code>91e81c8</code></a> Merge pull request <a href="https://github-redirect.dependabot.com/webpack/webpack/issues/11190">#11190</a> from merceyz/patch-2</li>\n<li><a href="https://github.com/webpack/webpack/commit/087af7c2e60c152ab7f7728c44b9f3bba2c0a7d0"><code>087af7c</code></a> Merge branch \'webpack-4\' into patch-2</li>\n<li><a href="https://github.com/webpack/webpack/commit/f170b98959a48714dd1f081d10af7997fd324578"><code>f170b98</code></a> chore: only specify peerDependenciesMeta</li>\n<li><a href="https://github.com/webpack/webpack/commit/e7c690e054efac9bacb1f51669e01459d2d4a437"><code>e7c690e</code></a> fix: add missing optional peer dependencies</li>\n<li>See full diff in <a href="https://github.com/webpack/webpack/compare/v4.44.0...v4.44.1">compare view</a></li>\n</ul>\n</details>\n<br />\n\n\n[![Dependabot compatibility score](https://api.dependabot.com/badges/compatibility_score?dependency-name=webpack&package-manager=npm_and_yarn&previous-version=4.44.0&new-version=4.44.1)](https://dependabot.com/compatibility-score/?dependency-name=webpack&package-manager=npm_and_yarn&previous-version=4.44.0&new-version=4.44.1)\n\nDependabot will resolve any conflicts with this PR as long as you don\'t alter it yourself. You can also trigger a rebase manually by commenting `@dependabot rebase`.\n\n[//]: # (dependabot-automerge-start)\nIf all status checks pass Dependabot will automatically merge this pull request.\n\n[//]: # (dependabot-automerge-end)\n\n---\n\n<details>\n<summary>Dependabot commands and options</summary>\n<br />\n\nYou can trigger Dependabot actions by commenting on this PR:\n- `@dependabot rebase` will rebase this PR\n- `@dependabot recreate` will recreate this PR, overwriting any edits that have been made to it\n- `@dependabot merge` will merge this PR after your CI passes on it\n- `@dependabot squash and merge` will squash and merge this PR after your CI passes on it\n- `@dependabot cancel merge` will cancel a previously requested merge and block automerging\n- `@dependabot reopen` will reopen this PR if it is closed\n- `@dependabot close` will close this PR and stop Dependabot recreating it. You can achieve the same result by closing it manually\n- `@dependabot ignore this major version` will close this PR and stop Dependabot creating any more for this major version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this minor version` will close this PR and stop Dependabot creating any more for this minor version (unless you reopen the PR or upgrade to it yourself)\n- `@dependabot ignore this dependency` will close this PR and stop Dependabot creating any more for this dependency (unless you reopen the P ...
#     'created_at': '2020-07-31T04:35:25Z',
#     'updated_at': '2020-07-31T04:41:29Z',
#     'closed_at': '2020-07-31T04:41:29Z',
#     'merged_at': '2020-07-31T04:41:29Z',
#     'merge_commit_sha': 'dacef93b7daa98ac27d49ef3455916e100bccfbe',
#     'assignee': None,
#     'assignees': [],
#     'requested_reviewers': [],
#     'requested_teams': [],
#     'labels': [{'id': 1542287469,
#       'node_id': 'MDU6TGFiZWwxNTQyMjg3NDY5',
#       'url': 'https://api.github.com/repos/Borewit/music-metadata-browser/labels/dependencies',
#       'name': 'dependencies',
#       'color': '0366d6',
#       'default': False,
#       'description': 'Pull requests that update a dependency file'}],
#     'milestone': None,
#     'draft': False,
#     'commits_url': 'https://api.github.com/repos/Borewit/music-metadata-browser/pulls/301/commits',
#     'review_comments_url': 'https://api.github.com/repos/Borewit/music-metadata-browser/pulls/301/comments',
#     'review_comment_url': 'https://api.github.com/repos/Borewit/music-metadata-browser/pulls/comments{/number}',
#     'comments_url': 'https://api.github.com/repos/Borewit/music-metadata-browser/issues/301/comments',
#     'statuses_url': 'https://api.github.com/repos/Borewit/music-metadata-browser/statuses/81a613a832ad403aadf3b8e5e6d8611b3fdab400',
#     'head': {'label': 'Borewit:dependabot/npm_and_yarn/webpack-4.44.1',
#      'ref': 'dependabot/npm_and_yarn/webpack-4.44.1',
#      'sha': '81a613a832ad403aadf3b8e5e6d8611b3fdab400',
#      'user': {'login': 'Borewit',
#       'id': 23255260,
#       'node_id': 'MDQ6VXNlcjIzMjU1MjYw',
#       'avatar_url': 'https://avatars0.githubusercontent.com/u/23255260?v=4',
#       'gravatar_id': '',
#       'url': 'https://api.github.com/users/Borewit',
#       'html_url': 'https://github.com/Borewit',
#       'followers_url': 'https://api.github.com/users/Borewit/followers',
#       'following_url': 'https://api.github.com/users/Borewit/following{/other_user}',
#       'gists_url': 'https://api.github.com/users/Borewit/gists{/gist_id}',
#       'starred_url': 'https://api.github.com/users/Borewit/starred{/owner}{/repo}',
#       'subscriptions_url': 'https://api.github.com/users/Borewit/subscriptions',
#       'organizations_url': 'https://api.github.com/users/Borewit/orgs',
#       'repos_url': 'https://api.github.com/users/Borewit/repos',
#       'events_url': 'https://api.github.com/users/Borewit/events{/privacy}',
#       'received_events_url': 'https://api.github.com/users/Borewit/received_events',
#       'type': 'User',
#       'site_admin': False},
#      'repo': {'id': 138642657,
#       'node_id': 'MDEwOlJlcG9zaXRvcnkxMzg2NDI2NTc=',
#       'name': 'music-metadata-browser',
#       'full_name': 'Borewit/music-metadata-browser',
#       'private': False,
#       'owner': {'login': 'Borewit',
#        'id': 23255260,
#        'node_id': 'MDQ6VXNlcjIzMjU1MjYw',
#        'avatar_url': 'https://avatars0.githubusercontent.com/u/23255260?v=4',
#        'gravatar_id': '',
#        'url': 'https://api.github.com/users/Borewit',
#        'html_url': 'https://github.com/Borewit',
#        'followers_url': 'https://api.github.com/users/Borewit/followers',
#        'following_url': 'https://api.github.com/users/Borewit/following{/other_user}',
#        'gists_url': 'https://api.github.com/users/Borewit/gists{/gist_id}',
#        'starred_url': 'https://api.github.com/users/Borewit/starred{/owner}{/repo}',
#        'subscriptions_url': 'https://api.github.com/users/Borewit/subscriptions',
#        'organizations_url': 'https://api.github.com/users/Borewit/orgs',
#        'repos_url': 'https://api.github.com/users/Borewit/repos',
#        'events_url': 'https://api.github.com/users/Borewit/events{/privacy}',
#        'received_events_url': 'https://api.github.com/users/Borewit/received_events',
#        'type': 'User',
#        'site_admin': False},
#       'html_url': 'https://github.com/Borewit/music-metadata-browser',
#       'description': 'Browser version of music-metadata parser Supporting a wide range of audio and tag formats.',
#       'fork': False,
# ...
#       'issue_events_url': 'https://api.github.com/repos/whytecreations/reviera/issues/events{/number}',
#       'events_url': 'https://api.github.com/repos/whytecreations/reviera/events',
#       'assignees_url': 'https://api.github.com/repos/whytecreations/reviera/assignees{/user}',
#       'branches_url': 'https://api.github.com/repos/whytecreations/reviera/branches{/branch}',
#       'tags_url': 'https://api.github.com/repos/whytecreations/reviera/tags',
#       'blobs_url': 'https://api.github.com/repos/whytecreations/reviera/git/blobs{/sha}',
#       'git_tags_url': 'https://api.github.com/repos/whytecreations/reviera/git/tags{/sha}',
#       'git_refs_url': 'https://api.github.com/repos/whytecreations/reviera/git/refs{/sha}',
#       'trees_url': 'https://api.github.com/repos/whytecreations/reviera/git/trees{/sha}',
#       'statuses_url': 'https://api.github.com/repos/whytecreations/reviera/statuses/{sha}',
#       'languages_url': 'https://api.github.com/repos/whytecreations/reviera/languages',
#       'stargazers_url': 'https://api.github.com/repos/whytecreations/reviera/stargazers',
#       'contributors_url': 'https://api.github.com/repos/whytecreations/reviera/contributors',
#       'subscribers_url': 'https://api.github.com/repos/whytecreations/reviera/subscribers',
#       'subscription_url': 'https://api.github.com/repos/whytecreations/reviera/subscription',
#       'commits_url': 'https://api.github.com/repos/whytecreations/reviera/commits{/sha}',
#       'git_commits_url': 'https://api.github.com/repos/whytecreations/reviera/git/commits{/sha}',
#       'comments_url': 'https://api.github.com/repos/whytecreations/reviera/comments{/number}',
#       'issue_comment_url': 'https://api.github.com/repos/whytecreations/reviera/issues/comments{/number}',
#       'contents_url': 'https://api.github.com/repos/whytecreations/reviera/contents/{+path}',
#       'compare_url': 'https://api.github.com/repos/whytecreations/reviera/compare/{base}...{head}',
#       'merges_url': 'https://api.github.com/repos/whytecreations/reviera/merges',
#       'archive_url': 'https://api.github.com/repos/whytecreations/reviera/{archive_format}{/ref}',
#       'downloads_url': 'https://api.github.com/repos/whytecreations/reviera/downloads',
#       'issues_url': 'https://api.github.com/repos/whytecreations/reviera/issues{/number}',
#       'pulls_url': 'https://api.github.com/repos/whytecreations/reviera/pulls{/number}',
#       'milestones_url': 'https://api.github.com/repos/whytecreations/reviera/milestones{/number}',
#       'notifications_url': 'https://api.github.com/repos/whytecreations/reviera/notifications{?since,all,participating}',
#       'labels_url': 'https://api.github.com/repos/whytecreations/reviera/labels{/name}',
#       'releases_url': 'https://api.github.com/repos/whytecreations/reviera/releases{/id}',
#       'deployments_url': 'https://api.github.com/repos/whytecreations/reviera/deployments',
#       'created_at': '2019-06-29T20:14:16Z',
#       'updated_at': '2019-09-18T23:36:31Z',
#       'pushed_at': '2020-07-31T04:41:28Z',
#       'git_url': 'git://github.com/whytecreations/reviera.git',
#       'ssh_url': 'git@github.com:whytecreations/reviera.git',
#       'clone_url': 'https://github.com/whytecreations/reviera.git',
#       'svn_url': 'https://github.com/whytecreations/reviera',
#       'homepage': None,
#       'size': 22402,
#       'stargazers_count': 0,
#       'watchers_count': 0,
#       'language': 'HTML',
#       'has_issues': True,
#       'has_projects': True,
#       'has_downloads': True,
#       'has_wiki': True,
#       'has_pages': False,
#       'forks_count': 0,
#       'mirror_url': None,
#       'archived': False,
#       'disabled': False,
#       'open_issues_count': 5,
#       'license': None,
#       'forks': 0,
#       'open_issues': 5,
#       'watchers': 0,
#       'default_branch': 'master'}},
#     '_links': {'self': {'href': 'https://api.github.com/repos/whytecreations/reviera/pulls/6'},
#      'html': {'href': 'https://github.com/whytecreations/reviera/pull/6'},
#      'issue': {'href': 'https://api.github.com/repos/whytecreations/reviera/issues/6'},
#      'comments': {'href': 'https://api.github.com/repos/whytecreations/reviera/issues/6/comments'},
#      'review_comments': {'href': 'https://api.github.com/repos/whytecreations/reviera/pulls/6/comments'},
#      'review_comment': {'href': 'https://api.github.com/repos/whytecreations/reviera/pulls/comments{/number}'},
#      'commits': {'href': 'https://api.github.com/repos/whytecreations/reviera/pulls/6/commits'},
#      'statuses': {'href': 'https://api.github.com/repos/whytecreations/reviera/statuses/57ca6207587b45393b23ff9b0cfad07101f7da50'}},
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'merged': False,
#     'mergeable': None,
#     'rebaseable': None,
#     'mergeable_state': 'unknown',
#     'merged_by': None,
#     'comments': 0,
#     'review_comments': 0,
#     'maintainer_can_modify': False,
#     'commits': 1,
#     'additions': 33,
#     'deletions': 14,
#     'changed_files': 1}},
#   'public': True,
#   'created_at': '2020-07-31T04:41:29Z',
#   'org': {'id': 23049942,
#    'login': 'whytecreations',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/orgs/whytecreations',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/23049942?'}},
#  {'id': '13068779521',
#   'type': 'PushEvent',
#   'actor': {'id': 57344531,
#    'login': 'ghanshyamjarvis',
#    'display_login': 'ghanshyamjarvis',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/ghanshyamjarvis',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/57344531?'},
#   'repo': {'id': 283724272,
#    'name': 'ghanshyamjarvis/circleci_mysql_connect',
#    'url': 'https://api.github.com/repos/ghanshyamjarvis/circleci_mysql_connect'},
#   'payload': {'push_id': 5459515767,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/circleci-project-setup',
#    'head': '67b1758d9217ceaab4315e0be3c4c9761dd965ca',
#    'before': '95bf7928c36958cd1dcd56d28b9597144092fd0b',
#    'commits': [{'sha': '67b1758d9217ceaab4315e0be3c4c9761dd965ca',
#      'author': {'email': '57344531+ghanshyamjarvis@users.noreply.github.com',
#       'name': 'ghanshyamjarvis'},
#      'message': 'Update config.yml',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/ghanshyamjarvis/circleci_mysql_connect/commits/67b1758d9217ceaab4315e0be3c4c9761dd965ca'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:29Z'},
#  {'id': '13068779514',
#   'type': 'PushEvent',
#   'actor': {'id': 13454744,
#    'login': 'Charliiee',
#    'display_login': 'Charliiee',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Charliiee',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/13454744?'},
#   'repo': {'id': 159876842,
#    'name': 'Charliiee/dotfiles',
#    'url': 'https://api.github.com/repos/Charliiee/dotfiles'},
#   'payload': {'push_id': 5459515761,
#    'size': 4,
#    'distinct_size': 4,
#    'ref': 'refs/heads/master',
#    'head': 'ea7e10a138f5d9b9d5eb0bd259ad2f703cd39610',
#    'before': '26619f62da964bda0649a591f71ec8f033a46bfd',
#    'commits': [{'sha': 'd59dabfcf187303b74e3de2d61fe07976b822add',
#      'author': {'email': 'carlin.afonso@gmail.com', 'name': 'Charliiee'},
#      'message': 'Add Obsession plugin (thanks tpope :heart:)',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Charliiee/dotfiles/commits/d59dabfcf187303b74e3de2d61fe07976b822add'},
#     {'sha': '78b4a34d047452eaf2b3d185dc5db0cd63da8825',
#      'author': {'email': 'carlin.afonso@gmail.com', 'name': 'Charliiee'},
#      'message': 'Add reminder to execute Obsess and start tracking Session\n\nAlso add info on status to check whether status update is enabled',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Charliiee/dotfiles/commits/78b4a34d047452eaf2b3d185dc5db0cd63da8825'},
#     {'sha': 'f656f6ca9e17269136cb1c10f34ebd7c019ece04',
#      'author': {'email': 'carlin.afonso@gmail.com', 'name': 'Charliiee'},
#      'message': 'Restore vim/nvim session on tmux restore',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Charliiee/dotfiles/commits/f656f6ca9e17269136cb1c10f34ebd7c019ece04'},
#     {'sha': 'ea7e10a138f5d9b9d5eb0bd259ad2f703cd39610',
#      'author': {'email': 'carlin.afonso@gmail.com', 'name': 'Charliiee'},
#      'message': 'Add Tmux Plugin Manager automatically when installing this dotfiles',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/Charliiee/dotfiles/commits/ea7e10a138f5d9b9d5eb0bd259ad2f703cd39610'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:29Z'},
#  {'id': '13068779524',
#   'type': 'PushEvent',
#   'actor': {'id': 166869,
#    'login': 'skysign',
#    'display_login': 'skysign',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/skysign',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/166869?'},
#   'repo': {'id': 229871088,
#    'name': 'skysign/WSAPT',
#    'url': 'https://api.github.com/repos/skysign/WSAPT'},
#   'payload': {'push_id': 5459515760,
#    'size': 1,
#    'distinct_size': 1,
#    'ref': 'refs/heads/master',
#    'head': 'adff4da2bbf91bfed6191bf7b6b002d29daf8305',
#    'before': '76b46fc0c6808aca83c46e03122d6bdb0be45e62',
#    'commits': [{'sha': 'adff4da2bbf91bfed6191bf7b6b002d29daf8305',
#      'author': {'email': 'kade.kim@machbase.com', 'name': 'Kade Kim'},
#      'message': 'BOJ 11055번 가장 큰 증가 부분 수열\n\n문제링크 : https://www.acmicpc.net/problem/11055',
#      'distinct': True,
#      'url': 'https://api.github.com/repos/skysign/WSAPT/commits/adff4da2bbf91bfed6191bf7b6b002d29daf8305'}]},
#   'public': True,
#   'created_at': '2020-07-31T04:41:29Z'},
#  {'id': '13068779517',
#   'type': 'WatchEvent',
#   'actor': {'id': 24503757,
#    'login': 'Booooooooooo',
#    'display_login': 'Booooooooooo',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/Booooooooooo',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/24503757?'},
#   'repo': {'id': 139609621,
#    'name': 'yulunzhang/RCAN',
#    'url': 'https://api.github.com/repos/yulunzhang/RCAN'},
#   'payload': {'action': 'started'},
#   'public': True,
#   'created_at': '2020-07-31T04:41:29Z'},
#  {'id': '13068779507',
#   'type': 'IssueCommentEvent',
#   'actor': {'id': 59044298,
#    'login': 'fathurnov',
#    'display_login': 'fathurnov',
#    'gravatar_id': '',
#    'url': 'https://api.github.com/users/fathurnov',
#    'avatar_url': 'https://avatars.githubusercontent.com/u/59044298?'},
#   'repo': {'id': 116965925,
#    'name': 'shurillu/CTBot',
#    'url': 'https://api.github.com/repos/shurillu/CTBot'},
#   'payload': {'action': 'created',
#    'issue': {'url': 'https://api.github.com/repos/shurillu/CTBot/issues/17',
#     'repository_url': 'https://api.github.com/repos/shurillu/CTBot',
#     'labels_url': 'https://api.github.com/repos/shurillu/CTBot/issues/17/labels{/name}',
#     'comments_url': 'https://api.github.com/repos/shurillu/CTBot/issues/17/comments',
#     'events_url': 'https://api.github.com/repos/shurillu/CTBot/issues/17/events',
#     'html_url': 'https://github.com/shurillu/CTBot/issues/17',
#     'id': 405438779,
#     'node_id': 'MDU6SXNzdWU0MDU0Mzg3Nzk=',
#     'number': 17,
#     'title': 'mybot.testconnection() OK but mybotSendMessage() NOK (return 0)',
#     'user': {'login': 'Franck06200',
#      'id': 47227247,
#      'node_id': 'MDQ6VXNlcjQ3MjI3MjQ3',
#      'avatar_url': 'https://avatars1.githubusercontent.com/u/47227247?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/Franck06200',
#      'html_url': 'https://github.com/Franck06200',
#      'followers_url': 'https://api.github.com/users/Franck06200/followers',
#      'following_url': 'https://api.github.com/users/Franck06200/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/Franck06200/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/Franck06200/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/Franck06200/subscriptions',
#      'organizations_url': 'https://api.github.com/users/Franck06200/orgs',
#      'repos_url': 'https://api.github.com/users/Franck06200/repos',
#      'events_url': 'https://api.github.com/users/Franck06200/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/Franck06200/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'labels': [],
#     'state': 'closed',
#     'locked': False,
#     'assignee': None,
#     'assignees': [],
#     'milestone': None,
#     'comments': 4,
#     'created_at': '2019-01-31T21:00:57Z',
#     'updated_at': '2020-07-31T04:41:29Z',
#     'closed_at': '2019-02-27T16:37:21Z',
#     'author_association': 'NONE',
#     'active_lock_reason': None,
#     'body': 'Hello\r\nI am running NodeMCU 1.0\r\nArduino IDE\r\nBoard 2.4.2\r\nYour last CTBot version (1.2.0) downloaded from Github today.\r\n\r\nMy Problems : \r\n1/ myBot.wifiConnect(ssid, pass) is working but does not return any connection information.\r\n2/ myBot.testConnection() is OK\r\n3/ myBot.sendMessage(ChatId, "TEST") is not working (return 0)\r\n\r\nI have checked my internet connection. The NodeMcu can reach google (443)\r\nI am able to send me telegram with same token and ChatId via my laptop using the browser (api.telegram.org/......)\r\n\r\nDo you have any clue to solve it ?\r\nWhy is there any message back after myBot.wifiConnect(ssid, pass) ?\r\n\r\nGrazie mille.\r\n\r\n\r\nHere my program:\r\n#include "CTBot.h" // Need ArduinoJson library 5.13.2 or lesser\r\n#include <ESP8266WiFi.h>\r\n#include <WiFiClientSecure.h>\r\n#include <WiFiClient.h>\r\n\r\nWiFiClientSecure client;\r\nCTBot myBot;\r\n\r\nString ssid  = "Livebox-04B8";\r\nString pass  = "mySSID";\r\nString token = "XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX";\r\nuint32_t ChatId = -111111111;  // changed for security purpose\r\n\r\nvoid setup() {\r\n\r\nSerial.begin(9600);\r\nSerial.println("Starting TelegramBot...");\r\nmyBot.wifiConnect(ssid, pass);\r\n\r\n  // set the telegram bot token\r\n  myBot.setTelegramToken(token);\r\n\r\n  // check if all things are ok\r\n  if (myBot.testConnection())\r\n    Serial.println("\\nCTBOTtestConnection OK");\r\n  else\r\n    Serial.println("\\nCTBOTtestConnection NOK");\r\n}\r\n\r\nvoid loop() {\r\n  Serial.print("Sending a message via CTBot");\r\n  Serial.println(" with bot token " + token);\r\n   Serial.println(myBot.sendMessage(ChatId, "TEST!"));\r\n  delay (30000);\r\n}\r\n',
#     'performed_via_github_app': None},
#    'comment': {'url': 'https://api.github.com/repos/shurillu/CTBot/issues/comments/666915334',
#     'html_url': 'https://github.com/shurillu/CTBot/issues/17#issuecomment-666915334',
#     'issue_url': 'https://api.github.com/repos/shurillu/CTBot/issues/17',
#     'id': 666915334,
#     'node_id': 'MDEyOklzc3VlQ29tbWVudDY2NjkxNTMzNA==',
#     'user': {'login': 'fathurnov',
#      'id': 59044298,
#      'node_id': 'MDQ6VXNlcjU5MDQ0Mjk4',
#      'avatar_url': 'https://avatars3.githubusercontent.com/u/59044298?v=4',
#      'gravatar_id': '',
#      'url': 'https://api.github.com/users/fathurnov',
#      'html_url': 'https://github.com/fathurnov',
#      'followers_url': 'https://api.github.com/users/fathurnov/followers',
#      'following_url': 'https://api.github.com/users/fathurnov/following{/other_user}',
#      'gists_url': 'https://api.github.com/users/fathurnov/gists{/gist_id}',
#      'starred_url': 'https://api.github.com/users/fathurnov/starred{/owner}{/repo}',
#      'subscriptions_url': 'https://api.github.com/users/fathurnov/subscriptions',
#      'organizations_url': 'https://api.github.com/users/fathurnov/orgs',
#      'repos_url': 'https://api.github.com/users/fathurnov/repos',
#      'events_url': 'https://api.github.com/users/fathurnov/events{/privacy}',
#      'received_events_url': 'https://api.github.com/users/fathurnov/received_events',
#      'type': 'User',
#      'site_admin': False},
#     'created_at': '2020-07-31T04:41:29Z',
#     'updated_at': '2020-07-31T04:41:29Z',
#     'author_association': 'NONE',
#     'body': "Sir @shurillu can I ask you, why sensor reading is become slow when I connect with the CTbot? If I don't use the CTbot the sensor reading is become fast again.",
#     'performed_via_github_app': None}},
#   'public': True,
#   'created_at': '2020-07-31T04:41:29Z'}]

# %% [markdown]
# ## 其它用法

# %%
payload = {'key1': 'value1', 'key2': 'value2'}
r = requests.get("http://httpbin.org/get", params=payload)
json.loads(r.text)
# Out:
# {'args': {'key1': 'value1', 'key2': 'value2'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/get?key1=value1&key2=value2'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)
# Out:
# {'args': {},
#  'data': '',
#  'files': {},
#  'form': {'key': 'value'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate',
#   'Content-Length': '9',
#   'Content-Type': 'application/x-www-form-urlencoded',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.19.1'},
#  'json': None,
#  'origin': '123.195.194.127, 123.195.194.127',
#  'url': 'https://httpbin.org/post'}

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})
json.loads(r.text)

# %% [markdown]
# ## 作業目標
#
# * 比較一下範例檔案中的「r.text」與「json.loads(r.text)」讀出來的內容有什麼差異
# * 自行尋找一個合適的 API 接口做練習，並且查看其回傳內容
#     * https://cat-fact.herokuapp.com/facts (來源：https://alexwohlbruck.github.io/cat-facts/)
#     * http://odata.wra.gov.tw/v4/RealtimeWaterLevel (來源：https://data.gov.tw/dataset/25768)
